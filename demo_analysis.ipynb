# %% [markdown]
# # GOLD Data Science Demo

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-50, 50, 200)
y = np.sin(x/10)

plt.figure()
plt.plot(x, y)
plt.title("Demo Radiance Profile")
plt.xlabel("Latitude")
plt.ylabel("Radiance")
